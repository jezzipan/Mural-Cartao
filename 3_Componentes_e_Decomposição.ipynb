# %% [markdown]
# <a href="https://colab.research.google.com/github/jezzipan/Mural-Cartao/blob/master/3_Componentes_e_Decomposi%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#
# <img src="https://media.eadbox.com/system/uploads/saas/devise_logo/5e407cf9bf392e001feb33df/Logo%2010.PNG" width="100px" style="color:gray;" />
#
# <h2>Trading com Dados </h2>
#
# <hr>
# <b>Curso</b> : Análise de Séries Temporais<br>
# <b>Tópico</b> : Componentes e Decomposição<br>
# <b>Professor</b> : Robson Fernandes<br>
# <hr>
#
#
#
#
# <center>

# %% [markdown]
# ### Instalação de Bibliotecas

# %%
pip install yfinance

# %% [markdown]
# #### Importação das Bibliotecas

# %%
import pandas as pd
import matplotlib.pylab as plt
import yfinance as yf
import warnings
import matplotlib
import statsmodels.api as sm
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### Configuração do Layout dos Gráficos

# %%
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'G'

# %% [markdown]
# ### Download do Conjunto De Dados - Petrobras

# %% [markdown]
# Nosso conjunto de dados será baseado nas ações da empresa Petróleo Brasileiro S.A. — Petrobras (PETR4.SA).

# %%
series_petr4 = yf.download("PETR4.SA", start="2015-01-01", end="2020-06-06")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
series_petr4.head(5)
# Out:
#             Open  High   Low  Close  Adj Close    Volume
# Date
# 2015-01-02  9.99  9.99  9.35   9.36   8.683469  49559500
# 2015-01-05  9.14  9.19  8.53   8.56   7.941292  78385100
# 2015-01-06  8.71  8.83  8.04   8.28   7.681531  84723300
# 2015-01-07  8.56  8.73  8.36   8.67   8.043342  85531000
# 2015-01-08  8.79  9.39  8.74   9.23   8.562866  83306300

# %% [markdown]
# #### Visualização da Série Temporal
# #### OPEN (Preço de Abertura)

# %%
series_petr4[["Open"]].plot(figsize = (19, 4)) 
plt.show()

# %% [markdown]
# ### Decomposição da Série Temporal - Modelo Aditivo

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
series_petr4_open = series_petr4.drop(['High', 'Low', 'Close', 'Adj Close', 'Volume'], axis=1)

# %%
series_petr4_open.head(2)
# Out:
#             Open
# Date
# 2015-01-02  9.99
# 2015-01-05  9.14

# %%
decomposition = sm.tsa.seasonal_decompose(x=series_petr4_open, freq=30, model='additive')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# ### Decomposição da Série Temporal - Modelo Multiplicativo

# %%
decomposition = sm.tsa.seasonal_decompose(x=series_petr4_open, freq=30, model='multiplicative')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# ### Exercício 3
#
# Avaliar os componentes Aditivos e Multiplicativos da série das ações da Amazon, código <b>AMZN</b>
#
# https://finance.yahoo.com/quote/AMZN%2CAPI/
